-- %%
CREATE CATALOG IF NOT EXISTS beanalytic_case
COMMENT 'Unity Catalog';

CREATE SCHEMA IF NOT EXISTS beanalytic_case.landing
COMMENT 'Raw files and ingestion';

CREATE SCHEMA IF NOT EXISTS beanalytic_case.bronze
COMMENT 'Raw Delta tables';

CREATE SCHEMA IF NOT EXISTS beanalytic_case.silver
COMMENT 'Validated Delta tables';

CREATE SCHEMA IF NOT EXISTS beanalytic_case.gold
COMMENT 'Monthly analytical tables';
SHOW SCHEMAS IN beanalytic_case;

-- %%
CREATE VOLUME IF NOT EXISTS beanalytic_case.landing.raw_files
COMMENT 'Raw BCB files and Auto Loader state';

SHOW VOLUMES IN beanalytic_case.landing;
